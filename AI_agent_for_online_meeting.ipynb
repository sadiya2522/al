# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiya2522/al/blob/main/AI_agent_for_online_meeting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
a = gTTS(input("Enter any text:"))
# Out:
# Enter any text:hello hi

# %%
a.save("speech.mp3")

# %%
Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install SpeechRecognition pydub

# %%
from pydub import AudioSegment
#mp3 format to .wav format
mp3_file = "/content/meeting 2.mp3"
wav_file = "/content/meeting 2.wav"
sound = AudioSegment.from_mp3(mp3_file)
sound.export(wav_file, format="wav")
# Out:
# <_io.BufferedRandom name='/content/meeting 2.wav'>

# %%
import speech_recognition as sr
reco = sr.Recognizer()
with sr.AudioFile("/content/meeting 2.wav") as source:
  audio_data = reco.record(source)
  print("Transcript: ",reco.recognize_google(audio_data))
# Out:
# Transcript:  being that it is 12:00 p.m. I will call the special meeting to order can I have a mover and secondary for the adoption of the agenda please counselor fuel counts the rocky beer resolved at the agenda for January 10th special meeting of council be approved thank you we are going to add on our question period so if there's anybody in the online gallery that has any questions please just unmute yourself and put your hand up or on mute yourself I'm not seeing any so we will move on to the building sustainable communities Grant applications can I have a mover and a second or please cancel the dean Council Rocky period for funding through the building sustainable communities program to defray project cost for the following projects you know the Community Club playground project with a budget of 75,000 the Springfield pathway system with the budget of $225,000 dollars the Springfield Trading Post with a budget of 50,000 dollars and the Springfield Aquatic and Wellness Center wi
# ...

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
s = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ...

# %%
t = ''' being that it is 12:00 p.m. I will call the special meeting to order can I have a mover and secondary for
the adoption of the agenda please counselor fuel counts the rocky beer resolved at the agenda for January 10th special
 meeting of council be approved thank you we are going to add on our question period so if there's anybody in the
 online gallery that has any questions please just unmute yourself and put your hand up or on mute yourself
 I'm not seeing any so we will move on to the building sustainable communities Grant applications can I have a mover
 and a second or please cancel the dean Council Rocky period for funding through the building sustainable communities
 program to defray project cost for the following projects you know the Community Club playground project with a budget
  of 75,000 the Springfield pathway system with the budget of $225,000 dollars the Springfield Trading Post with a
  budget of 50,000 dollars and the Springfield Aquatic and Wellness Center with the budget of 3 million 700,000
   thank you I know that we've opened it up to apply for more projects this year hopefully we'll get some funding for
   each and every one of those is there any other comments from Council Rocky I just like to apply the our
    Administration for moving forward with this and as we know the more I guess which we do call applications or
    projects or potential things that we can do for Community are for the better for us to apply for all and then
    in the long run see what it is that we end up with so the more opportunity we have the better it is for all so
    thank you very much for I know it's not always so easy to fill out Grant applications and things like that so I do
    appreciate all the work that they do and we should hear back in a couple months on these applications it's not
    clear I know the deadline for application is January 17th but they have an indicated a response time okay any other
     comments or questions from Council all those in favor Carrie 0 we do have a council meeting at 1 so we will
     adjourn until that time can I have them over and secondary Journey please cancel'''

# %%
result = s(t)
result[0].get('summary_text')
# Out:
# ' Community Club playground project with a budget of 75,000 dollars the Springfield pathway system with the budget of $225,000 and the Springfield Trading Post with a $50,000 budget of 50,000 . Building sustainable communities Grant applications for the following projects . The deadline for application is January 17th but they have an indicated a response time .'

# %%
from transformers import pipeline

# %%
a = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# ...

# %%
text = input("Enter the text: ")
print(a(text))
# Out:
# Enter the text:  Community Club playground project with a budget of 75,000 dollars the Springfield pathway system with the budget of $225,000 and the Springfield Trading Post with a $50,000 budget of 50,000 . Building sustainable communities Grant applications for the following projects . The deadline for application is January 17th but they have an indicated a response time .
# [{'label': 'NEGATIVE', 'score': 0.7777000665664673}]

# %%
qa = pipeline('question-answering')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# ...

# %%
c = ''' Community Club playground project with a budget of 75,000 the Springfield pathway system with the budget of $225,000 dollars the Springfield Trading Post with a  . 50,000 dollar budget . Springfield Aquatic and Wellness Center with the . budget of 3 million 700,000 . dollars .'''

# %%
q = "What was discussed in the meeting"

# %%
result = qa({'question': q,'context': c})
print(result)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/question_answering.py:390: FutureWarning: Passing a list of SQuAD examples to the pipeline is deprecated and will be removed in v5. Inputs should be passed using the `question` and `context` keyword arguments instead.
#   warnings.warn(
# {'score': 0.13532312214374542, 'start': 1, 'end': 89, 'answer': 'Community Club playground project with a budget of 75,000 the Springfield pathway system'}

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator
t = Translator()
text = input("Enter a text: ")
translated = t.translate(text,src="en",dest='korean')
print("translated text:",translated.text)
# Out:
# Enter a text:  Community Club playground project with a budget of 75,000 dollars the Springfield pathway system with the budget of $225,000 and the Springfield Trading Post with a $50,000 budget of 50,000 . Building sustainable communities Grant applications for the following projects . The deadline for application is January 17th but they have an indicated a response time .
# translated text: 예산이 75,000 달러 인 Community Club Playground Project는 225,000 달러의 예산을 가진 Springfield Pathway System과 50,000 달러의 예산이 5 만 달러 인 Springfield Trading Post입니다.지속 가능한 커뮤니티 구축은 다음 프로젝트에 대한 신청서를 부여합니다.신청 마감일은 1 월 17 일이지만 응답 시간이 표시됩니다.

# %%
import smtplib
from email.message import EmailMessage

# %%
SENDER_EMAIL = "nbnaidu1208@gmail.com"
APP_PASSWORD = "kdyi rxwp slhg jddo"

# %%
def send_email(summary, recipient):
    msg = EmailMessage()
    msg.set_content(summary)
    msg["Subject"] = "Meeting Summary"
    msg["From"] = SENDER_EMAIL
    msg["To"] = recipient

    try:
        with smtplib.SMTP_SSL("smtp.gmail.com", 465) as smtp:
            smtp.login(SENDER_EMAIL, APP_PASSWORD)
            smtp.send_message(msg)
        print("Email sent successfully!")
    except Exception as e:
        print("Failed to send email:", e)

# %%
summary_text = " Community Club playground project with a budget of 75,000 dollars the Springfield pathway system with the budget of $225,000 and the Springfield Trading Post with a $50,000 budget of 50,000 . Building sustainable communities Grant applications for the following projects . The deadline for application is January 17th but they have an indicated a response time ."
recipient_email = "nbnaidu1208@gmail.com"
send_email(summary_text, recipient_email)
# Out:
# Email sent successfully!
